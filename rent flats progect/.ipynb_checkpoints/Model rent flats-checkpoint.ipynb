# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
rent_base = pd.read_csv('rent_rielt_new.csv')
rent_base.head()
# Out:
#    district  metro   area  rooms  floor  gk    price  \
# 0      2.87    3.0   30.0      1    7.0   0  11000.0
# 1      1.74    3.0  100.0      3   11.0   1  27500.0
# 2      2.87    3.0  120.0      3    5.0   1  90750.0
# 3      1.74    3.0   45.0      1    2.0   0  21000.0
# 4      1.74    3.0   90.0      3   10.0   0  27500.0
#
#                                           adress
# 0              Кловский спуск, 20, Печерский р-н
# 1          Жилянская ул., 118, Шевченковский р-н
# 2             Драгомирова ул., 20, Печерский р-н
# 3  Вячеслава Липинского, 1/16, Шевченковский р-н
# 4     Тургеневская ул., 29-33, Шевченковский р-н

# %%
rent_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3278 entries, 0 to 3277
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   district  3278 non-null   float64
#  1   metro     3278 non-null   float64
#  2   area      3278 non-null   float64
#  3   rooms     3278 non-null   int64
#  4   floor     3278 non-null   float64
#  5   gk        3278 non-null   int64
#  6   price     3278 non-null   float64
#  7   adress    3278 non-null   object
# dtypes: float64(5), int64(2), object(1)
# memory usage: 205.0+ KB

# %%
rent_base['price'].max()
# Out:
# 137500.0

# %%
rent_base.describe()
# Out:
#           district        metro         area        rooms        floor  \
# count  3278.000000  3278.000000  3278.000000  3278.000000  3278.000000
# mean      1.576120     2.202563    64.029292     1.895363     8.292556
# std       0.606121     0.959907    36.655875     0.896729     6.103483
# min       1.000000     1.000000    18.000000     1.000000     1.000000
# 25%       1.190000     1.000000    42.000000     1.000000     3.000000
# 50%       1.220000     3.000000    52.000000     2.000000     7.000000
# 75%       1.740000     3.000000    75.000000     2.000000    12.000000
# max       2.870000     3.000000   389.000000     5.000000    31.000000
#
#                 gk          price
# count  3278.000000    3278.000000
# mean      0.213545   21823.528676
# std       0.409872   23228.542357
# min       0.000000    5000.000000
# 25%       0.000000   10000.000000
# 50%       0.000000   14000.000000
# 75%       0.000000   23000.000000
# max       1.000000  288750.000000

# %%
sns.pairplot(rent_base)

# %%
sns.distplot(rent_base['price'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.lmplot(x='area', y='price', data=rent_base)

# %%
X = rent_base[['district', 'metro', 'area',
               'rooms', 'floor', 'gk']]
y = rent_base['price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 7063.95563707,  1388.19885388,   516.83470199, -3055.03241478,
#           44.81306324,  4897.86801914])

# %%
lm.score(X_train,y_train)
# Out:
# 0.6592543332955904

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#           Coefficient
# district  7063.955637
# metro     1388.198854
# area       516.834702
# rooms    -3055.032415
# floor       44.813063
# gk        4897.868019

# %%
lm.score(X_test, y_test)
# Out:
# 0.6650143861374256

# %%
#predictions = lm.predict(X_test)
# for i in zip(y_train, predictions):
#     print(i)

# %%
predictions = lm.predict(X_test)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 6719.9081761940215
# MSE: 124906268.82052626
# RMSE: 11176.147315623854

# %%
import pickle

with open(r'Aleks_Alena_model.pickle', 'wb') as f:
    pickle.dump(lm, f)

# %%
predictions = lm.predict(np.array([1.18, 3, 46, 1, 12, 1]).reshape(1, -1))
predictions
# Out:
# array([17568.58538991])

# %%
import pickle

with open(r'Aleks_model_3.pickle', 'wb') as f:
    pickle.dump(lm, f)

# %%
from sklearn.ensemble import RandomForestRegressor
model_3 = RandomForestRegressor()
model_3.fit(X_train, y_train)
print(model_3.score(X_train, y_train))
# Out:
# 0.9430936967887151

# %%
model_3.score(X_test, y_test)
# Out:
# 0.7467058740209682

# %%
predict = model_3.predict(np.array([2.87, 3, 58, 2, 10, 1]).reshape(1, -1))
predict
# Out:
# array([35610.])
