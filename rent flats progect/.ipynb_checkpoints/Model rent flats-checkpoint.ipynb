# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
rent_base = pd.read_csv('rent4.csv')
rent_base.head()
# Out:
#    district  metro   area  rooms  floor  gk    price  \
# 0      1.74    1.0   50.0    2.0   11.0   1  27500.0
# 1      2.87    1.0   70.0    2.0   18.0   1  33000.0
# 2      1.18    2.0   34.0    1.0    7.0   0   8000.0
# 3      2.87    1.0   96.0    2.0   10.0   0  35750.0
# 4      2.87    1.0  127.0    3.0    4.0   0  20625.0
#
#                                               adress
# 0          Златоустовская ул., 30, Шевченковский р-н
# 1  Евгения Коновальца ул. (Щорса), 44а, Печерский...
# 2               Симиренко ул., 26а, Святошинский р-н
# 3  Михаила Омеляновича-Павленка ул. (Суворова), П...
# 4     Е. Коновальца ул. (Щорса), 32-г, Печерский р-н

# %%
rent_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3532 entries, 0 to 3531
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   district  3532 non-null   float64
#  1   metro     3532 non-null   float64
#  2   area      3532 non-null   float64
#  3   rooms     3532 non-null   float64
#  4   floor     3532 non-null   float64
#  5   gk        3532 non-null   int64
#  6   price     3532 non-null   float64
#  7   adress    3532 non-null   object
# dtypes: float64(6), int64(1), object(1)
# memory usage: 220.9+ KB

# %%
rent_base['price'].max()
# Out:
# 137500.0

# %%
rent_base.describe()
# Out:
#           district        metro         area        rooms        floor  \
# count  3532.000000  3532.000000  3532.000000  3532.000000  3532.000000
# mean      1.563080     1.827860    61.698893     1.831257     8.349094
# std       0.605527     0.963411    33.049227     0.852708     6.176360
# min       1.000000     1.000000    14.000000     1.000000     1.000000
# 25%       1.190000     1.000000    42.000000     1.000000     4.000000
# 50%       1.220000     1.000000    51.000000     2.000000     7.000000
# 75%       1.740000     3.000000    72.000000     2.000000    12.000000
# max       2.870000     3.000000   296.000000     5.000000    35.000000
#
#                 gk          price
# count  3532.000000    3532.000000
# mean      0.206682   19989.557333
# std       0.404983   18310.221977
# min       0.000000    4999.000000
# 25%       0.000000   10000.000000
# 50%       0.000000   13500.000000
# 75%       0.000000   22000.000000
# max       1.000000  137500.000000

# %%
sns.pairplot(rent_base)

# %%
sns.distplot(rent_base['price'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.lmplot(x='area', y='price', data=rent_base)

# %%
X = rent_base[['district', 'metro', 'area',
               'rooms', 'floor', 'gk']]
y = rent_base['price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 6331.60594691, -1320.42639538,   404.6447642 , -1162.13102595,
#           87.55550015,  4968.85538618])

# %%
lm.score(X_train,y_train)
# Out:
# 0.6637543215056008

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#           Coefficient
# district  6331.605947
# metro    -1320.426395
# area       404.644764
# rooms    -1162.131026
# floor       87.555500
# gk        4968.855386

# %%
lm.score(X_test, y_test)
# Out:
# 0.6279161499792669

# %%
#predictions = lm.predict(X_test)
# for i in zip(y_train, predictions):
#     print(i)

# %%
predictions = lm.predict(X_test)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 6719.9081761940215
# MSE: 124906268.82052626
# RMSE: 11176.147315623854

# %%
import pickle

with open(r'Aleks_Alena_model.pickle', 'wb') as f:
    pickle.dump(lm, f)

# %%
predictions = lm.predict(np.array([1.53, 2, 50, 1, 5, 0]).reshape(1, -1))
predictions
# Out:
# array([14473.49642169])

# %%
import pickle

with open(r'Aleks_model_2.pickle', 'wb') as f:
    pickle.dump(lm, f)
